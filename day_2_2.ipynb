# %% [markdown]
# <a href="https://colab.research.google.com/github/savarirohan3-byte/AIDS-Learning/blob/main/day_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'put', 'empty', 'themselves', 'at', 'until', 'elsewhere', 'eight', 'less', 'give', 'in', 'it', 'everything', 'many', 'last', 'thereafter', 'hers', 'of', 'whole', 'hundred', 'afterwards', 'but', 'made', 'own', 'noone', 'did', 'anything', 'became', 'enough', '’ll', 'seeming', 'sometime', 'whose', 'such', 'anyhow', 'after', 'whereupon', 'same', 'therein', 'sixty', 'never', 'where', 'and', 'about', '‘re', 'else', 'thereby', 'though', 'more', 'part', '’re', 'on', 'nor', 'thereupon', 'eleven', 'the', 'alone', 'keep', 'nevertheless', 'them', 'between', 'amongst', 'my', 'full', 'towards', 'formerly', 'moreover', 'beyond', 'within', 'rather', "'ve", 'so', 'because', 'even', 'than', "'d", 'perhaps', 'otherwise', 'using', 'has', 'there', 'while', 'may', 'next', 'still', 'due', 'get', 'whenever', 'top', 'also', 'everywhere', 'show', 'per', 'below', 'us', 'he', 'others', 'nine', 'except', 'bottom', 'those', 'anywhere', 'nobody', 'becoming', 'go', 'therefore', 'what', 'now', 'somewhere', 'why', 'n’t', 'against', 'anyone', 'quite', 'this', 'nothing', 'again', 'do', "n't", 'first', 'further', 'cannot', 'all', 'throughout', 'fifteen', 'to', "'m", 'hereby', 'only', 'myself', 'should', '‘d', 'forty', 'just', 'already', 'how', 'fifty', 'over', 'somehow', 'n‘t', 'every', 'been', 'seem', 'through', 'none', 'becomes', 'each', 'whereby', 'i', 'had', 'something', 'when', 'we', 'various', 'three', 'will', '‘s', 'does', 'done', 'onto', 'up', 'much', 'along', 'please', 'whereafter', 'from', 'amount', 'ten', 'too', 'several', '’m', 'they', 'almost', 'upon', 'can', 'besides', 'must', 'indeed', 'one', 'thence', 'without', 'least', '‘m', '’ve', 'not', 'however', 'together', 'your', 'since', 'unless', 'used', 'thus', 'front', 'latterly', 'both', 'see', 'everyone', 'into', 'seems', 'latter', 'whereas', 'beside', 'off', 'him', 'is', 'she', 'make', 'whom', 'who', 'across', 'seemed', 'would', 'yourself', 'here', 'third', 'serious', 'behind', 'whoever', 'few', 'nowhere', 'out', "'s", 'our', 'hereafter', 'twenty', 'some', 'meanwhile', 'no', 'via', 'five', 'twelve', 'you', 'itself', 'either', 'as', 'her', 'thru', 'toward', 'herein', 'once', '‘ve', 'although', 'six', 'anyway', '’s', 'ourselves', 'whence', 're', 'might', 'four', 'whither', 'any', "'ll", 'above', 'really', 'ca', 'always', 'neither', 'back', 'which', 'with', 'then', 'during', 'mine', 'down', 'someone', 'have', 'side', 'if', 'hereupon', 'or', 'sometimes', 'mostly', 'could', 'was', "'re", 'are', 'ever', 'its', 'move', 'two', 'call', 'an', 'me', 'beforehand', 'another', '’d', 'were', 'wherein', 'under', 'whatever', 'wherever', 'by', 'being', 'namely', 'regarding', 'hence', 'yet', 'become', 'be', 'a', 'around', 'yours', 'doing', 'their', 'name', 'yourselves', 'these', 'say', '‘ll', 'herself', 'that', 'his', 'often', 'for', 'ours', 'former', 'am', 'well', 'among', 'whether', 'very', 'other', 'himself', 'before', 'most', 'take'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop=True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True
